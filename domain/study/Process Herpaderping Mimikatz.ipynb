# %% [markdown]
# # Process Herpaderping Mimikatz
#
# This dataset represents the execution of a Process Herpaderping to obscure the intentions of a process by modifying the content on disk after the image has been mapped.
#
# # Datasets
# https://raw.githubusercontent.com/OTRF/Security-Datasets/master/datasets/atomic/windows/defense_evasion/host/cmd_process_herpaderping_snippingtool.zip
#
# # Reference
# https://www.cnblogs.com/bonelee/p/15384364.html
#
#
# # Adversary View
#
# ```powershell
# C:\Users\wardog>cd Desktop
#
# C:\Users\wardog\Desktop>ProcessHerpaderping.exe mimikatz.exe wardog.exe C:\Windows\system32\SnippingTool.exe
# Process Herpaderping Tool - Copyright (c) 2020 Johnny Shaw
# [12140:10252][OK]    Source File: "mimikatz.exe"
# [12140:10252][OK]    Target File: "wardog.exe"
# [12140:10252][INFO]  Copied source binary to target file
# [12140:10252][INFO]  Created image section for target
# [12140:10252][INFO]  Created process object, PID 8924
# [12140:10252][INFO]  Located target image entry RVA 0x000c3aec
# [12140:10252][OK]    Replacing target with "C:\Windows\system32\SnippingTool.exe"
# [12140:10252][OK]    Preparing target for execution
# [12140:10252][INFO]  Writing process parameters, remote PEB ProcessParameters 0x0000000000AED020
# [12140:10252][INFO]  Creating thread in process at entry point 0x00007FF733E63AEC
# [12140:10252][INFO]  Created thread, TID 12112
# [12140:10252][OK]    Waiting for herpaderped process to exit
# [12140:10252][OK]    Herpaderped process exited with code 0xc000013a
# [12140:10252][OK]    Process Herpaderp Succeeded
#
# C:\Users\wardog\Desktop>
# ```

# %%
procs = GET process from https://raw.githubusercontent.com/OTRF/Security-Datasets/master/datasets/atomic/windows/defense_evasion/host/cmd_process_herpaderping_snippingtool.zip where command_line LIKE '%'
# Out:
# <div><h4>Block Executed in 1 seconds</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>VARIABLE</th>
#       <th>TYPE</th>
#       <th>#(ENTITIES)</th>
#       <th>#(RECORDS)</th>
#       <th>artifact*</th>
#       <th>directory*</th>
#       <th>file*</th>
#       <th>process*</th>
#       <th>user-account*</th>
#       <th>windows-registry-key*</th>
#       <th>x-oca-asset*</th>
#       <th>x-oca-event*</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>procs</td>
#       <td>process</td>
#       <td>4</td>
#       <td>122</td>
#       <td>118</td>
#       <td>188</td>
#       <td>234</td>
#       <td>122</td>
#       <td>8</td>
#       <td>2</td>
#       <td>118</td>
#       <td>118</td>
#     </tr>
#   </tbody>
# </table><p>*Number of related records cached.</p></div>

# %% [markdown]
# # Find relate process extension with "exe"

# %%
sprocs = procs where command_line LIKE '%exe%'
# Out:
# <div><h4>Block Executed in 1 seconds</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>VARIABLE</th>
#       <th>TYPE</th>
#       <th>#(ENTITIES)</th>
#       <th>#(RECORDS)</th>
#       <th>artifact*</th>
#       <th>directory*</th>
#       <th>file*</th>
#       <th>process*</th>
#       <th>user-account*</th>
#       <th>windows-registry-key*</th>
#       <th>x-oca-asset*</th>
#       <th>x-oca-event*</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>sprocs</td>
#       <td>process</td>
#       <td>4</td>
#       <td>122</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table><p>*Number of related records cached.</p></div>

# %% [markdown]
# # There are 4 process are running in this dataset. And we found ProcessHerpadering.exe is excuting by mimikatz.exe from command line

# %%
DISP sprocs
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>pid</th>
#       <th>name</th>
#       <th>id</th>
#       <th>command_line</th>
#       <th>x_unique_id</th>
#       <th>created</th>
#       <th>binary_ref.name</th>
#       <th>binary_ref.id</th>
#       <th>binary_ref.hashes.'SHA-1'</th>
#       <th>binary_ref.hashes.MD5</th>
#       <th>binary_ref.hashes.'SHA-256'</th>
#       <th>binary_ref.parent_directory_ref.path</th>
#       <th>binary_ref.parent_directory_ref.id</th>
#       <th>parent_ref.pid</th>
#       <th>parent_ref.name</th>
#       <th>parent_ref.id</th>
#       <th>parent_ref.command_line</th>
#       <th>parent_ref.x_unique_id</th>
#       <th>parent_ref.created</th>
#       <th>parent_ref.parent_ref.pid</th>
#       <th>parent_ref.parent_ref.name</th>
#       <th>parent_ref.parent_ref.id</th>
#       <th>parent_ref.parent_ref.command_line</th>
#       <th>parent_ref.parent_ref.x_unique_id</th>
#       <th>parent_ref.parent_ref.created</th>
#       <th>parent_ref.binary_ref.name</th>
#       <th>parent_ref.binary_ref.id</th>
#       <th>parent_ref.binary_ref.hashes.'SHA-1'</th>
#       <th>parent_ref.binary_ref.hashes.MD5</th>
#       <th>parent_ref.binary_ref.hashes.'SHA-256'</th>
#       <th>parent_ref.binary_ref.parent_directory_ref.path</th>
#       <th>parent_ref.binary_ref.parent_directory_ref.id</th>
#       <th>parent_ref.creator_user_ref.user_id</th>
#       <th>parent_ref.creator_user_ref.id</th>
#       <th>creator_user_ref.user_id</th>
#       <th>creator_user_ref.id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10164</td>
#       <td>ProcessHerpaderping.exe</td>
#       <td>process--4c0c25ad-51d0-5883-ade9-d364387e1ed4</td>
#       <td>ProcessHerpaderping.exe  mimikatz.exe wardog.exe C:\windows\System32\SnippingTool.exe</td>
#       <td>{39e4a257-1289-5f98-472d-000000000700}</td>
#       <td>2020-10-27T12:28:57.061Z</td>
#       <td>ProcessHerpaderping.exe</td>
#       <td>file--2d6f2884-4ff9-5d9f-a7e5-3fc5e1f8c6a4</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>C:\Users\wardog\Desktop</td>
#       <td>directory--a0157638-19ed-5309-a828-eb616733ae0e</td>
#       <td>10032.0</td>
#       <td>cmd.exe</td>
#       <td>process--d56a7662-c194-53ac-94c6-7be0741c6f54</td>
#       <td>"C:\windows\system32\cmd.exe"</td>
#       <td>{39e4a257-1269-5f98-452d-000000000700}</td>
#       <td>None</td>
#       <td></td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>cmd.exe</td>
#       <td>file--bdb40b46-65f7-5a74-9516-60746576d4e7</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>C:\Windows\System32</td>
#       <td>directory--0a58d0c1-59e6-5afd-8252-dcd3f13e5622</td>
#       <td>None</td>
#       <td>None</td>
#       <td>WORKSTATION5\wardog</td>
#       <td>user-account--c8b6cbe8-e16c-5b03-948a-085d1333e43e</td>
#     </tr>
#     <tr>
#       <td>8924</td>
#       <td>wardog.exe</td>
#       <td>process--84fe5c72-6dad-5185-8ada-52c84af4ee0e</td>
#       <td>"wardog.exe"</td>
#       <td>{39e4a257-1289-5f98-482d-000000000700}</td>
#       <td>2020-10-27T12:28:57.129Z</td>
#       <td>wardog.exe</td>
#       <td>file--a62162c0-f37a-5126-8a36-706462857a97</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>C:\Users\wardog\Desktop</td>
#       <td>directory--a0157638-19ed-5309-a828-eb616733ae0e</td>
#       <td>10164.0</td>
#       <td>ProcessHerpaderping.exe</td>
#       <td>process--4c0c25ad-51d0-5883-ade9-d364387e1ed4</td>
#       <td>ProcessHerpaderping.exe  mimikatz.exe wardog.exe C:\windows\System32\SnippingTool.exe</td>
#       <td>{39e4a257-1289-5f98-472d-000000000700}</td>
#       <td>2020-10-27T12:28:57.061Z</td>
#       <td>10032.0</td>
#       <td>cmd.exe</td>
#       <td>process--d56a7662-c194-53ac-94c6-7be0741c6f54</td>
#       <td>"C:\windows\system32\cmd.exe"</td>
#       <td>{39e4a257-1269-5f98-452d-000000000700}</td>
#       <td>None</td>
#       <td>ProcessHerpaderping.exe</td>
#       <td>file--2d6f2884-4ff9-5d9f-a7e5-3fc5e1f8c6a4</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>C:\Users\wardog\Desktop</td>
#       <td>directory--a0157638-19ed-5309-a828-eb616733ae0e</td>
#       <td>WORKSTATION5\wardog</td>
#       <td>user-account--c8b6cbe8-e16c-5b03-948a-085d1333e43e</td>
#       <td>WORKSTATION5\wardog</td>
#       <td>user-account--c8b6cbe8-e16c-5b03-948a-085d1333e43e</td>
#     </tr>
#     <tr>
#       <td>552</td>
#       <td>conhost.exe</td>
#       <td>process--b1ccc754-7521-5604-9567-a8e2a4f4ef3b</td>
#       <td>\??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1</td>
#       <td>{39e4a257-1289-5f98-492d-000000000700}</td>
#       <td>2020-10-27T12:28:57.373Z</td>
#       <td>conhost.exe</td>
#       <td>file--9d6a9721-9948-53ff-83f8-3865bc03c727</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>C:\Windows\System32</td>
#       <td>directory--0a58d0c1-59e6-5afd-8252-dcd3f13e5622</td>
#       <td>8924.0</td>
#       <td>wardog.exe</td>
#       <td>process--84fe5c72-6dad-5185-8ada-52c84af4ee0e</td>
#       <td>"wardog.exe"</td>
#       <td>{39e4a257-1289-5f98-482d-000000000700}</td>
#       <td>2020-10-27T12:28:57.129Z</td>
#       <td>10164.0</td>
#       <td>ProcessHerpaderping.exe</td>
#       <td>process--4c0c25ad-51d0-5883-ade9-d364387e1ed4</td>
#       <td>ProcessHerpaderping.exe  mimikatz.exe wardog.exe C:\windows\System32\SnippingTool.exe</td>
#       <td>{39e4a257-1289-5f98-472d-000000000700}</td>
#       <td>2020-10-27T12:28:57.061Z</td>
#       <td>wardog.exe</td>
#       <td>file--a62162c0-f37a-5126-8a36-706462857a97</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>C:\Users\wardog\Desktop</td>
#       <td>directory--a0157638-19ed-5309-a828-eb616733ae0e</td>
#       <td>WORKSTATION5\wardog</td>
#       <td>user-account--c8b6cbe8-e16c-5b03-948a-085d1333e43e</td>
#       <td>WORKSTATION5\wardog</td>
#       <td>user-account--c8b6cbe8-e16c-5b03-948a-085d1333e43e</td>
#     </tr>
#     <tr>
#       <td>10032</td>
#       <td>cmd.exe</td>
#       <td>process--d56a7662-c194-53ac-94c6-7be0741c6f54</td>
#       <td>"C:\windows\system32\cmd.exe"</td>
#       <td>{39e4a257-1269-5f98-452d-000000000700}</td>
#       <td>None</td>
#       <td>cmd.exe</td>
#       <td>file--bdb40b46-65f7-5a74-9516-60746576d4e7</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>C:\Windows\System32</td>
#       <td>directory--0a58d0c1-59e6-5afd-8252-dcd3f13e5622</td>
#       <td></td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td></td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Find child processes created by ProcessHerpaderping.exe to see what are these process doing.

# %%
tasks = FIND process CREATED BY procs
ProcessHerpaderping = GET process FROM tasks WHERE [process:name = 'ProcessHerpaderping.exe']
ProcessHerpaderping_child = FIND process CREATED by ProcessHerpaderping
DISP ProcessHerpaderping_child ATTR name, command_line
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>command_line</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>wardog.exe</td>
#       <td>"wardog.exe"</td>
#     </tr>
#   </tbody>
# </table>
# <div><h4>Block Executed in 1 seconds</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>VARIABLE</th>
#       <th>TYPE</th>
#       <th>#(ENTITIES)</th>
#       <th>#(RECORDS)</th>
#       <th>artifact*</th>
#       <th>directory*</th>
#       <th>file*</th>
#       <th>process*</th>
#       <th>user-account*</th>
#       <th>windows-registry-key*</th>
#       <th>x-oca-asset*</th>
#       <th>x-oca-event*</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>tasks</td>
#       <td>process</td>
#       <td>3</td>
#       <td>233</td>
#       <td>294</td>
#       <td>490</td>
#       <td>583</td>
#       <td>304</td>
#       <td>13</td>
#       <td>5</td>
#       <td>294</td>
#       <td>294</td>
#     </tr>
#     <tr>
#       <td>ProcessHerpaderping</td>
#       <td>process</td>
#       <td>2</td>
#       <td>21</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>ProcessHerpaderping_child</td>
#       <td>process</td>
#       <td>1</td>
#       <td>194</td>
#       <td>294</td>
#       <td>490</td>
#       <td>583</td>
#       <td>306</td>
#       <td>13</td>
#       <td>5</td>
#       <td>294</td>
#       <td>294</td>
#     </tr>
#   </tbody>
# </table><p>*Number of related records cached.</p></div>

# %% [markdown]
# # Investigate whether this suspious process had any network traffic

# %%
networktraffic = FIND network-traffic CREATED BY ProcessHerpaderping
DISP networktraffic ATTR dst_ref.value, dst_port
# Out:
# <div><h4>Block Executed in 1 seconds</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>VARIABLE</th>
#       <th>TYPE</th>
#       <th>#(ENTITIES)</th>
#       <th>#(RECORDS)</th>
#       <th>artifact*</th>
#       <th>directory*</th>
#       <th>file*</th>
#       <th>process*</th>
#       <th>user-account*</th>
#       <th>windows-registry-key*</th>
#       <th>x-oca-asset*</th>
#       <th>x-oca-event*</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>networktraffic</td>
#       <td>network-traffic</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table><p>*Number of related records cached.</p></div>

# %% [markdown]
# # Take a deeper look to child process of ProcessHerpadering's child process

# %%
ProcessHerpaderping_child_child = FIND process CREATED BY ProcessHerpaderping_child
DISP ProcessHerpaderping_child_child ATTR name, command_line
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>command_line</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>conhost.exe</td>
#       <td>\??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1</td>
#     </tr>
#   </tbody>
# </table>
# <div><h4>Block Executed in 1 seconds</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>VARIABLE</th>
#       <th>TYPE</th>
#       <th>#(ENTITIES)</th>
#       <th>#(RECORDS)</th>
#       <th>artifact*</th>
#       <th>directory*</th>
#       <th>file*</th>
#       <th>process*</th>
#       <th>user-account*</th>
#       <th>windows-registry-key*</th>
#       <th>x-oca-asset*</th>
#       <th>x-oca-event*</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ProcessHerpaderping_child_child</td>
#       <td>process</td>
#       <td>1</td>
#       <td>125</td>
#       <td>335</td>
#       <td>533</td>
#       <td>665</td>
#       <td>348</td>
#       <td>14</td>
#       <td>5</td>
#       <td>335</td>
#       <td>335</td>
#     </tr>
#   </tbody>
# </table><p>*Number of related records cached.</p></div>

# %% [markdown]
# # This step is to see what files are read/written/excuted by ProcessHerpadering_child_child.
#
# > FIND : wardog.exe

# %%
ProcessHerpaderping_file = FIND file LINKED ProcessHerpaderping_child_child
DISP ProcessHerpaderping_file ATTR name, parent_directory_ref.path
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>parent_directory_ref.path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>CoreUIComponents.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>sechost.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>shlwapi.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>gdi32.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>SHCore.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>windows.storage.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>profapi.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>advapi32.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>rpcrt4.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>ntmarta.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>clbcatq.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>KernelBase.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>TextInputFramework.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>shell32.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>wardog.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>conhost.exe</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>wardog.exe</td>
#       <td>C:\Users\wardog\Desktop</td>
#     </tr>
#     <tr>
#       <td>uxtheme.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>kernel32.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>kernel.appcore.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>ntdll.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>cryptsp.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>umpdc.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>comctl32.dll</td>
#       <td>C:\Windows\WinSxS\amd64_microsoft.windows.common-controls_6595b64144ccf1df_6.0.18362.1139_none_9e7bf2d3e4605ac6</td>
#     </tr>
#     <tr>
#       <td>imm32.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>msvcp_win.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>oleaut32.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>cfgmgr32.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>user32.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>combase.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>msctf.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>msvcrt.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>ucrtbase.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>bcryptprimitives.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>win32u.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>CoreMessaging.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>WinTypes.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>dwmapi.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>gdi32full.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>powrprof.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>iertutil.dll</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#   </tbody>
# </table>
# <div><h4>Block Executed in 1 seconds</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>VARIABLE</th>
#       <th>TYPE</th>
#       <th>#(ENTITIES)</th>
#       <th>#(RECORDS)</th>
#       <th>artifact*</th>
#       <th>directory*</th>
#       <th>file*</th>
#       <th>process*</th>
#       <th>user-account*</th>
#       <th>windows-registry-key*</th>
#       <th>x-oca-asset*</th>
#       <th>x-oca-event*</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ProcessHerpaderping_file</td>
#       <td>file</td>
#       <td>43</td>
#       <td>730</td>
#       <td>456</td>
#       <td>719</td>
#       <td>853</td>
#       <td>474</td>
#       <td>28</td>
#       <td>6</td>
#       <td>456</td>
#       <td>456</td>
#     </tr>
#   </tbody>
# </table><p>*Number of related records cached.</p></div>
